# %% [markdown]
# ## index
#
# 1. conditional statement
#   - if-else
# 2. iteration statement
#   - for
#   - while
#   - break & next

# %% [markdown]
# # 1. conditional statement

# %% [markdown]
# if-else문

# %%
job.type <- 'A'
if (job.type == 'B') {
  bonus <- 200 
} else {
  bonsu <= 100
}

print(bonus)

# %%
score <- 85

if (score>90) {
  grade <- 'A'
} else if (score > 80) {
  grade <- 'b'
} else {
  grade <- 'F'
}

# %% [markdown]
# and = &
# or = |

# %%
a <- 10
b <- 20
if (a>5 & b>5) {
  print(a+b)
}
if (a>5 | b>40) {
  print(a*b)
}

# %% [markdown]
# ifelse 문
# - 조건에 따라 둘 중 하나의 값 또는 변수를 선택할깨 사용
# - 삼항 연산자와 비슷하다

# %%
a <- 10
b <- 20

c <- ifelse(a>b, a, b) # c에는 b가 저장된다

# %% [markdown]
# # 2. iteration statement

# %% [markdown]
# 기본 for문

# %%
for (i in 1:5){ #i=1,2,3,4,5 일때 실행된다
  print(i)      # 1 2 3 4 5
}
# Out:
# [1] "*"
# [1] "*"
# [1] "*"
# [1] "*"
# [1] "*"

# %%
for (i in 1:9){
  cat('2 *', i,'=',2*i,'\n')    # 2*1=2.  2*2=4.  2*3=6.  ..... 2*9=18
}

# %%
for (i in 1;20){
  if (i%%2==0) { # 짝수인지
    print(i)
  }
}

# %%
sum <- 0
for(i in 1:100){
  sum <- sum +i # sum에 i값을 누적
}
print(sum)

# %% [markdown]
# iris 데이터셋에서 꽃잎의 길이에 따른 분류 작업

# %%
norow <- nrow(iris) # iris 행의 수

mylabel <- c() # 비어있는 벡터 선언

for (i in 1:norow) {
  if (iris$Petal.Length[i] <= 1.6) { # 꽃잎의 길이에 따라 레이블 결정 
      mylabel[i] <= 'L'
  } else if (iris$Petal.Length[i] >= 5.1) {
      mylabel[i] <= 'H'
  } else {
      mylabel[i] <- 'M'
  }
}

print(mylabel) # 레이블 출력
newds <- data.frame(iris$Petal.Length, mylabel) #꽃잎의 길이와 레이블 결합
head(newds) # 새로운 데이터셋 내용 출력

# %% [markdown]
# while 문

# %%
sum <- 0
i <- 1
while (i <= 100){
  sum <- sum+i #sum에 i를 누적
  i<- i+1
}

# %% [markdown]
# break와 next

# %%
# break
sum <- 0
for (i in 1:10){
  sum <- sum+i
  if (i>=5) break
}
sum

# %%
# next
sum <- 0
for (i in 1:10) {
  if (i%%2 == 0) next # 짝수일댄 continue
  sum <- sum+i
}
sum
